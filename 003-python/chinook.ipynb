# %% [markdown]
# # Pandas Interview Questions

# %%
# %pip install pandas
# Out:
# Requirement already satisfied: pandas in /home/hossein/Documents/Coding/Analytics/interview-resources/.venv/lib64/python3.11/site-packages (2.1.1)
# Requirement already satisfied: numpy>=1.23.2 in /home/hossein/Documents/Coding/Analytics/interview-resources/.venv/lib64/python3.11/site-packages (from pandas) (1.26.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/hossein/Documents/Coding/Analytics/interview-resources/.venv/lib64/python3.11/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /home/hossein/Documents/Coding/Analytics/interview-resources/.venv/lib64/python3.11/site-packages (from pandas) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in /home/hossein/Documents/Coding/Analytics/interview-resources/.venv/lib64/python3.11/site-packages (from pandas) (2023.3)
# Requirement already satisfied: six>=1.5 in /home/hossein/Documents/Coding/Analytics/interview-resources/.venv/lib64/python3.11/site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
#
# [notice] A new release of pip available: 22.3.1 -> 23.3
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import sqlite3

# %% [markdown]
# ## Beginner ⭐

# %%
with sqlite3.connect("chinook.db") as db_connection:
        tables = list(pd.read_sql_query("SELECT name FROM sqlite_master WHERE type='table';", db_connection)['name'])
        data = {tbl : pd.read_sql_query(f"SELECT * from {tbl}", db_connection) for tbl in tables}

# %% [markdown]
# ### Retrieve Data:
# - **Chinook**: Retrieve the names of all albums.

# %%
print(tables)
# Out:
# ['Album', 'Artist', 'Customer', 'Employee', 'Genre', 'Invoice', 'InvoiceLine', 'MediaType', 'Playlist', 'PlaylistTrack', 'Track']

# %%
data['Album'].Title.head()
# Out:
# 0    For Those About To Rock We Salute You
# 1                        Balls to the Wall
# 2                        Restless and Wild
# 3                        Let There Be Rock
# 4                                 Big Ones
# Name: Title, dtype: object

# %% [markdown]
# ### Filtering Data:
# - **Chinook**: Find tracks that belong to the 'Jazz' genre.

# %%
data['Genre']
# Out:
#     GenreId                Name
# 0         1                Rock
# 1         2                Jazz
# 2         3               Metal
# 3         4  Alternative & Punk
# 4         5       Rock And Roll
# 5         6               Blues
# 6         7               Latin
# 7         8              Reggae
# 8         9                 Pop
# 9        10          Soundtrack
# 10       11          Bossa Nova
# 11       12      Easy Listening
# 12       13         Heavy Metal
# 13       14            R&B/Soul
# 14       15   Electronica/Dance
# 15       16               World
# 16       17         Hip Hop/Rap
# 17       18     Science Fiction
# 18       19            TV Shows
# 19       20    Sci Fi & Fantasy
# 20       21               Drama
# 21       22              Comedy
# 22       23         Alternative
# 23       24           Classical
# 24       25               Opera

# %%
TrackGenre_df = data['Track'].merge(data['Genre'], left_on='GenreId', right_on='GenreId' , how='inner')
TrackGenre_df.head()
# Out:
#    TrackId                                   Name_x  AlbumId  MediaTypeId  \
# 0        1  For Those About To Rock (We Salute You)        1            1
# 1        2                        Balls to the Wall        2            2
# 2        3                          Fast As a Shark        3            2
# 3        4                        Restless and Wild        3            2
# 4        5                     Princess of the Dawn        3            2
#
#    GenreId                                           Composer  Milliseconds  \
# 0        1          Angus Young, Malcolm Young, Brian Johnson        343719
# 1        1                                               None        342562
# 2        1  F. Baltes, S. Kaufman, U. Dirkscneider & W. Ho...        230619
# 3        1  F. Baltes, R.A. Smith-Diesel, S. Kaufman, U. D...        252051
# 4        1                         Deaffy & R.A. Smith-Diesel        375418
#
#       Bytes  UnitPrice Name_y
# 0  11170334       0.99   Rock
# 1   5510424       0.99   Rock
# 2   3990994       0.99   Rock
# 3   4331779       0.99   Rock
# 4   6290521       0.99   Rock

# %%
TrackGenre_df[TrackGenre_df.Name_y=='Jazz']
# Out:
#       TrackId                                 Name_x  AlbumId  MediaTypeId  \
# 1297       63                             Desafinado        8            1
# 1298       64                      Garota De Ipanema        8            1
# 1299       65  Samba De Uma Nota Só (One Note Samba)        8            1
# 1300       66                      Por Causa De Você        8            1
# 1301       67                                  Ligia        8            1
# ...       ...                                    ...      ...          ...
# 1422     2530                           Little Linda      204            1
# 1423     2531                     End Of Romanticism      204            1
# 1424     3349                                 Amanda      262            5
# 1425     3350                              Despertar      262            5
# 1426     3357                            OAM's Blues      267            5
#
#       GenreId         Composer  Milliseconds     Bytes  UnitPrice Name_y
# 1297        2             None        185338   5990473       0.99   Jazz
# 1298        2             None        285048   9348428       0.99   Jazz
# 1299        2             None        137273   4535401       0.99   Jazz
# 1300        2             None        169900   5536496       0.99   Jazz
# 1301        2             None        251977   8226934       0.99   Jazz
# ...       ...              ...           ...       ...        ...    ...
# 1422        2      Jeremy Wall        264019   8958743       0.99   Jazz
# 1423        2     Rick Strauss        320078  10553155       0.99   Jazz
# 1424        2     Luca Gusella        246503   4011615       0.99   Jazz
# 1425        2  Andrea Dulbecco        307385   4821485       0.99   Jazz
# 1426        2   Aaron Goldberg        266936   4292028       0.99   Jazz
#
# [130 rows x 10 columns]

# %%
Genre_df = data['Genre']
jazz_genre_id = int(Genre_df[Genre_df.Name=='Jazz'].GenreId.iloc[0])
print(jazz_genre_id)
Track_df = data['Track']
Track_df[Track_df.GenreId==jazz_genre_id]
# Out:
# 2
#       TrackId                                   Name  AlbumId  MediaTypeId  \
# 62         63                             Desafinado        8            1
# 63         64                      Garota De Ipanema        8            1
# 64         65  Samba De Uma Nota Só (One Note Samba)        8            1
# 65         66                      Por Causa De Você        8            1
# 66         67                                  Ligia        8            1
# ...       ...                                    ...      ...          ...
# 2529     2530                           Little Linda      204            1
# 2530     2531                     End Of Romanticism      204            1
# 3348     3349                                 Amanda      262            5
# 3349     3350                              Despertar      262            5
# 3356     3357                            OAM's Blues      267            5
#
#       GenreId         Composer  Milliseconds     Bytes  UnitPrice
# 62          2             None        185338   5990473       0.99
# 63          2             None        285048   9348428       0.99
# 64          2             None        137273   4535401       0.99
# 65          2             None        169900   5536496       0.99
# 66          2             None        251977   8226934       0.99
# ...       ...              ...           ...       ...        ...
# 2529        2      Jeremy Wall        264019   8958743       0.99
# 2530        2     Rick Strauss        320078  10553155       0.99
# 3348        2     Luca Gusella        246503   4011615       0.99
# 3349        2  Andrea Dulbecco        307385   4821485       0.99
# 3356        2   Aaron Goldberg        266936   4292028       0.99
#
# [130 rows x 9 columns]
